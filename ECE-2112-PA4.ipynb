# %%
import pandas as pd

# %%
df = pd.read_excel('board2.xlsx')
df
# Out:
#    Name  Gender             Track  Hometown  Math  Electronics  GEAS  \
# 0    S1    Male   Instrumentation     Luzon    58           89    75
# 1    S2  Female     Communication  Mindanao    52           75    90
# 2    S3  Female   Instrumentation  Mindanao    83           74    77
# 3    S4    Male   Instrumentation   Visayas    65           58    91
# 4    S5    Male     Communication     Luzon    59           86    43
# 5    S6  Female  Microelectronics   Visayas    88           45    86
# 6    S7  Female   Instrumentation     Luzon    66           60    60
# 7    S8    Male   Instrumentation     Luzon    49           81    64
# 8    S9    Male   Instrumentation     Luzon    50           36    63
# 9   S10    Male  Microelectronics  Mindanao    80           84    61
# 10  S11  Female     Communication   Visayas    48           56    48
# 11  S12    Male     Communication   Visayas    89           67    84
# 12  S13  Female  Microelectronics     Luzon    88           35    83
# 13  S14  Female  Microelectronics     Luzon    83           77    89
# 14  S15  Female  Microelectronics  Mindanao    69           41    40
# 15  S16  Female     Communication     Luzon    71           70    87
# 16  S17  Female  Microelectronics  Mindanao    81           79    77
# 17  S18    Male     Communication   Visayas    81           40    81
# 18  S19    Male  Microelectronics     Luzon    79           63    79
# 19  S20  Female     Communication  Mindanao    59           60    62
# 20  S21  Female  Microelectronics   Visayas    83           51    68
# 21  S22  Female     Communication   Visayas    64           39    89
# 22  S23    Male   Instrumentation     Luzon    84           70    74
# 23  S24  Female  Microelectronics   Visayas    85           45    60
# 24  S25    Male     Communication     Luzon    74           91    94
# 25  S26  Female   Instrumentation   Visayas    71           47    83
# 26  S27    Male  Microelectronics   Visayas    70           47    40
# 27  S28    Male     Communication   Visayas    85           53    80
# 28  S29    Male   Instrumentation  Mindanao    73           48    71
# 29  S30    Male   Instrumentation     Luzon    78           81    57
#
#     Communication
# 0              78
# 1              52
# 2              57
# 3              68
# 4              88
# 5              83
# 6              48
# 7              53
# 8              42
# 9              44
# 10             67
# 11             64
# 12             43
# 13             73
# 14             86
# 15             81
# 16             45
# 17             52
# 18             71
# 19             85
# 20             72
# 21             58
# 22             47
# 23             41
# 24             42
# 25             62
# 26             86
# 27             53
# 28             62
# 29             56

# %% [markdown]
# **A. VISAYAS COMMUNICATION DATAFRAME**

# %%
df['Average'] = (
    
    +df['Math'] +
    df['GEAS'] +
    df['Electronics']
) / 3

# %%
VisComm = df.loc[(df['Hometown'] == 'Visayas') & (df['Track'] == 'Communication')].reset_index()
VisComm.loc[:,['Name','Gender','Math','Electronics','Average']]
# Out:
#   Name  Gender  Math  Electronics    Average
# 0  S11  Female    48           56  50.666667
# 1  S12    Male    89           67  80.000000
# 2  S18    Male    81           40  67.333333
# 3  S22  Female    64           39  64.000000
# 4  S28    Male    85           53  72.666667

# %%
print('Number of Rows: ',len(VisComm))
# Out:
# Number of Rows:  5

# %% [markdown]
# **B. VISAYAS FEMALE DATAFRAME**

# %%
VisFemale = df.loc[(df['Hometown'] == 'Visayas') & (df['Gender'] == 'Female'),['Name','Track','GEAS','Electronics','Average']].reset_index()
VisFemale
# Out:
#    index Name             Track  GEAS  Electronics    Average
# 0      5   S6  Microelectronics    86           45  73.000000
# 1     10  S11     Communication    48           56  50.666667
# 2     20  S21  Microelectronics    68           51  67.333333
# 3     21  S22     Communication    89           39  64.000000
# 4     23  S24  Microelectronics    60           45  63.333333
# 5     25  S26   Instrumentation    83           47  67.000000

# %%
VisFemale.loc[(VisFemale['Average']>=60)]
# Out:
#    index Name             Track  GEAS  Electronics    Average
# 0      5   S6  Microelectronics    86           45  73.000000
# 2     20  S21  Microelectronics    68           51  67.333333
# 3     21  S22     Communication    89           39  64.000000
# 4     23  S24  Microelectronics    60           45  63.333333
# 5     25  S26   Instrumentation    83           47  67.000000

# %% [markdown]
# **C. Category-Average Visualization**

# %%
track_mean = df.groupby('Track')['Average'].mean().reset_index()
display(track_mean)
# Out:
#               Track    Average
# 0     Communication  69.233333
# 1   Instrumentation  67.866667
# 2  Microelectronics  68.533333

# %%
gender_mean = df.groupby('Gender')['Average'].mean().reset_index()
display(gender_mean)
# Out:
#    Gender    Average
# 0  Female  67.644444
# 1    Male  69.444444

# %%
hometown_mean = df.groupby('Hometown')['Average'].mean().reset_index()
display(hometown_mean)
# Out:
#    Hometown    Average
# 0     Luzon  70.722222
# 1  Mindanao  68.380952
# 2   Visayas  66.272727

# %%
track_max = track_mean.max()
track_max
# Out:
# Track      Microelectronics
# Average           69.233333
# dtype: object

# %%
gender_max = gender_mean.max()
gender_max
# Out:
# Gender          Male
# Average    69.444444
# dtype: object

# %%
hometown_max = hometown_mean.max()
hometown_max
# Out:
# Hometown      Visayas
# Average     70.722222
# dtype: object

# %%
plt.figure(figsize=(20, 5))

# %%
plt.subplot(1, 3, 1)
plt.bar(track_mean['Track'], track_mean['Average'])
plt.title('Mean Average by Track')
plt.xlabel('Track')
plt.ylabel('Mean Average Score')

plt.subplot(1, 3, 2)
plt.bar(gender_mean['Gender'], gender_mean['Average'])
plt.title('Mean Average by Gender')
plt.xlabel('Gender')
plt.ylabel('Average')

plt.subplot(1, 3, 3)
plt.bar(hometown_mean['Hometown'], hometown_mean['Average'])
plt.title('Mean Average by Hometown')
plt.xlabel('Hometown')
plt.ylabel('Average')

plt.tight_layout()
plt.show()

print("The Track that has the highest mean average is:\n")
print(track_max)

print("\nThe Gender that has the highest mean average is:\n")
print(gender_max)

print("\nThe Hometown that has the highest mean average is:\n")
print(hometown_max)
# Out:
# The Track that has the highest mean average is:
#
# Track      Microelectronics
# Average           69.233333
# dtype: object
#
# The Gender that has the highest mean average is:
#
# Gender          Male
# Average    69.444444
# dtype: object
#
# The Hometown that has the highest mean average is:
#
# Hometown      Visayas
# Average     70.722222
# dtype: object
